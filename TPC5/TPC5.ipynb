# %%
sala1= (150, [], "Twilight")
sala2= (150,[], "Hannibal")
cinema1 = [sala1]
cinema2 = [sala2]

def listar (cinema):
    lista = []
    for sala in cinema:
        lista.append (sala [2])
    return lista

def disponível (cinema, filme, lugar):
    res = False
    for sala in cinema:
        if filme == sala [2]:
            if lugar not in sala[1]:
                res = True
    return res

def vendebilhete (cinema, filme, lugar ):
    if disponível (cinema, filme, lugar) == True:
        for sala in cinema:
            if filme == sala [2]:
                if lugar not in sala [1]:
                    res = True
        return res

def vendebilhete (cinema, filme, lugar):
    if disponível (cinema, filme, lugar):
        for sala in cinema:
            if filme == sala [2]:
                sala [1] .append(lugar)
        return cinema

def listardisponibilidade (cinema):
    disponibilidades = []
    for sala in cinema:
        info = (sala [2], sala [0]- len (sala [1]))
        disponibilidades.append(info)
    return disponibilidades

def inserirsala (cinema, sala):
    if sala not in cinema:
        cinema. append (sala)
    return cinema

def menu():
    print("""
        (1). listar (cinema)
        (2). disponivel (cinema, filme, lugar)
        (3). vendebilhete (cinema, filme, lugar)
        (4). listar disponiblidade (cinema)
        (5). inserirsala
        """)

num = int (input ("Escreve a sua opção"))

if num == 1:
    lista = listar (cinema1, cinema2) 
    for filmes in lista:
        print(filmes)

if num == 2:
    cinema = str (input ("Escolha o cinema que quer"))
    filme = str (input ("Qual é o filme que quer ver?"))
    lugar = int (input ( "Escolha o seu lugar"))
    
    cond = disponível (cinema, filme, lugar) 
    if cond:
        print ("o lugar que deseja está disponivel")
    else:
        print ("o lugar que deseja não está")

if num == 3:
    cinema = str (input ("Escolha o cinema"))
    filme = str (input ("Qual é o filme que quer ver"))
    lugar = int ( input (" Escolha o seu lugar"))
    vendebilhete (cinema, filme, lugar)

if num == 4:
    print(listardisponibilidade(str(input("Escolha o cinema"))))

if num == 5:
    cinema = str(input("Escolha o cinema"))
    num_lugares = int(input("Insira o numero de lugares"))
    
    n = int(input("Quantos lugares estão vendidos"))
    lista = []
    for i in range(n):
        num = int(input("Qual o numero do lugar?"))
        lista.append(num)
    filme = str(input("Digite o filme que quer ver"))
    sala = (num_lugares, lista, filme)
    inserirsala(cinema, sala)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 58
#      55 num = int (input ("Escreve a sua opção"))
#      57 if num == 1:
# ---> 58     lista = listar (cinema1, cinema2)
#      59     for filmes in lista:
#      60         print(filmes)
#
# TypeError: listar() takes 1 positional argument but 2 were given
